# %%
import pandas as pd
import numpy as np
import sys
import os
from IPython.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import warnings
warnings.filterwarnings("ignore")
# Out:
# <style>.container { width:90% !important; }</style>

# %%
# Set the directory containing all raw data
rootDir = '/Users/alia/Documents/Github/DoDContractApp/Raw Data/Service Contracts'

# Loop through subfolders in directory
for dirName, subdirList, fileList in os.walk(rootDir):
    print('Found directory: %s' % dirName)
    
    # If there are files in the folder
    if len(fileList)>0:
        
        for fname in fileList:
            if fname.endswith('.csv'): 
                print('\t%s' % fname)
                filepath = f'{dirName}/{fname}'
                df = pd.read_csv(filepath)
                df = df[['contract_award_unique_key',
                         'total_obligated_amount',
                         'award_base_action_date',
                         'awarding_agency_name',
                         'awarding_sub_agency_name',
                         'awarding_office_name',
                         'recipient_name',
                         'primary_place_of_performance_state_code',
                         'product_or_service_code_description',
                         'dod_claimant_program_description',
                         'type_of_contract_pricing',
                         'award_type',
                         'contract_bundling',
                         'solicitation_procedures',
                         'naics_code',
                         'naics_description',
                         'last_modified_date']]
        
                df.to_csv(f'/Users/alia/Documents/Github/DoDContractApp/Clean Data/Service Contracts/{fname}',index=False)
# Out:
# Found directory: /Users/alia/Documents/Github/DoDContractApp/Raw Data/Service Contracts
# 	FY2016.csv
# 	FY2017.csv
# 	FY2015.csv
# 	FY2014.csv
# 	FY2013.csv
# 	FY2012.csv
# 	FY2022.csv
# 	FY2020.csv
# 	FY2021.csv
# 	FY2019.csv
# 	FY2018.csv

# %%
# Set the directory containing all raw data
rootDir = '/Users/alia/Documents/Github/DoDContractApp/Clean Data/Service Contracts'

# Loop through subfolders in directory
for dirName, subdirList, fileList in os.walk(rootDir):
    print('Found directory: %s' % dirName)
    
    # If there are files in the folder
    if len(fileList)>0:
        
        col_list = ['awarding_sub_agency_name',
                    'awarding_office_name',
                    'recipient_name',
                    'primary_place_of_performance_state_code',
                    'product_or_service_code_description',
                    'dod_claimant_program_description',
                    'type_of_contract_pricing',
                    'award_type',
                    'contract_bundling',
                    'solicitation_procedures',
                    'naics_description']
        
        for col in col_list:
            print(col)
            
            # Create empty dataframe
            df = pd.DataFrame()
        
            for fname in fileList:

                if fname.endswith('.csv'): 
                    print('\t%s' % fname)
                    filepath = f'{dirName}/{fname}'
                    dat = pd.read_csv(filepath)

                    sub = dat.groupby([col])[['total_obligated_amount']].sum()
                    sub.reset_index(inplace=True)
                    sub = sub.sort_values('total_obligated_amount',ascending=False)
                    sub = sub.reset_index(drop=True)
                    yr = int(fname[2:6])
                    sub['fiscal_year']=yr

                    if len(sub)>10 and col!='primary_place_of_performance_state_code':
                        # Add together groups with smaller total obligations as "Other"
                        other = sub[11:]
                        other_sum = other['total_obligated_amount'].sum()

                        sub = sub[:10]
                        sub.loc[len(sub)] = ['OTHER',other_sum,yr]
                        sub = sub.sort_values('total_obligated_amount',ascending=True)
                        sub = sub.reset_index(drop=True)

                    df = df.append(sub)

            df.to_csv(f'/Users/alia/Documents/Github/DoDContractApp/Clean Data/Plot Data/{col}.csv',index=False)
# Out:
# Found directory: /Users/alia/Documents/Github/DoDContractApp/Clean Data/Service Contracts
# awarding_sub_agency_name
# 	FY2016.csv
# 	FY2017.csv
# 	FY2015.csv
# 	FY2014.csv
# 	FY2013.csv
# 	FY2012.csv
# 	FY2022.csv
# 	FY2020.csv
# 	FY2021.csv
# 	FY2019.csv
# 	FY2018.csv
# awarding_office_name
# 	FY2016.csv
# 	FY2017.csv
# 	FY2015.csv
# 	FY2014.csv
# 	FY2013.csv
# 	FY2012.csv
# 	FY2022.csv
# 	FY2020.csv
# 	FY2021.csv
# 	FY2019.csv
# 	FY2018.csv
# recipient_name
# 	FY2016.csv
# 	FY2017.csv
# 	FY2015.csv
# 	FY2014.csv
# 	FY2013.csv
# 	FY2012.csv
# 	FY2022.csv
# 	FY2020.csv
# 	FY2021.csv
# 	FY2019.csv
# 	FY2018.csv
# primary_place_of_performance_state_code
# 	FY2016.csv
# 	FY2017.csv
# 	FY2015.csv
# 	FY2014.csv
# 	FY2013.csv
# 	FY2012.csv
# 	FY2022.csv
# 	FY2020.csv
# 	FY2021.csv
# 	FY2019.csv
# 	FY2018.csv
# product_or_service_code_description
# 	FY2016.csv
# 	FY2017.csv
# 	FY2015.csv
# 	FY2014.csv
# 	FY2013.csv
# 	FY2012.csv
# 	FY2022.csv
# 	FY2020.csv
# 	FY2021.csv
# 	FY2019.csv
# 	FY2018.csv
# dod_claimant_program_description
# 	FY2016.csv
# 	FY2017.csv
# 	FY2015.csv
# 	FY2014.csv
# 	FY2013.csv
# 	FY2012.csv
# 	FY2022.csv
# 	FY2020.csv
# 	FY2021.csv
# 	FY2019.csv
# 	FY2018.csv
# type_of_contract_pricing
# 	FY2016.csv
# 	FY2017.csv
# 	FY2015.csv
# 	FY2014.csv
# 	FY2013.csv
# 	FY2012.csv
# 	FY2022.csv
# 	FY2020.csv
# 	FY2021.csv
# 	FY2019.csv
# 	FY2018.csv
# award_type
# 	FY2016.csv
# 	FY2017.csv
# 	FY2015.csv
# 	FY2014.csv
# 	FY2013.csv
# 	FY2012.csv
# 	FY2022.csv
# 	FY2020.csv
# 	FY2021.csv
# 	FY2019.csv
# 	FY2018.csv
# contract_bundling
# 	FY2016.csv
# 	FY2017.csv
# 	FY2015.csv
# 	FY2014.csv
# 	FY2013.csv
# 	FY2012.csv
# 	FY2022.csv
# 	FY2020.csv
# 	FY2021.csv
# 	FY2019.csv
# 	FY2018.csv
# solicitation_procedures
# 	FY2016.csv
# 	FY2017.csv
# 	FY2015.csv
# 	FY2014.csv
# 	FY2013.csv
# 	FY2012.csv
# 	FY2022.csv
# 	FY2020.csv
# 	FY2021.csv
# 	FY2019.csv
# 	FY2018.csv
# naics_description
# 	FY2016.csv
# 	FY2017.csv
# 	FY2015.csv
# 	FY2014.csv
# 	FY2013.csv
# 	FY2012.csv
# 	FY2022.csv
# 	FY2020.csv
# 	FY2021.csv
# 	FY2019.csv
# 	FY2018.csv

# %%
# Set the directory containing all raw data
rootDir = '/Users/alia/Desktop/Service Contracts Clean'

# Loop through subfolders in directory
for dirName, subdirList, fileList in os.walk(rootDir):
    print('Found directory: %s' % dirName)
    
    # If there are files in the folder
    if len(fileList)>0:
        
        col_list = ['awarding_sub_agency_name',
                    'awarding_office_name',
                    'recipient_name']
        
        for col in col_list:
            print(col)
            
            # Create empty dataframe
            df = pd.DataFrame()
        
            for fname in fileList:

                if fname.endswith('.csv'): 
                    print('\t%s' % fname)
                    filepath = f'{dirName}/{fname}'
                    dat = pd.read_csv(filepath)

                    sub = pd.DataFrame({'count' : test22.groupby( ['awarding_sub_agency_name'] ).size()}).reset_index()
                    sub = sub.sort_values('count',ascending=False)
                    sub = sub.reset_index(drop=True)
                    yr = int(fname[2:6])
                    sub['fiscal_year']=yr

                    if len(sub)>10:
                        # Add together groups with smaller total obligations as "Other"
                        other = sub[11:]
                        other_sum = other['count'].sum()

                        sub = sub[:10]
                        sub.loc[len(sub)] = ['OTHER',other_sum,yr]
                        sub = sub.sort_values('count',ascending=True)
                        sub = sub.reset_index(drop=True)

                    df = df.append(sub)

            df.to_csv(f'/Users/alia/Documents/Github/DoDContractApp/Clean Data/Plot Data/{col}_count.csv',index=False)
# Out:
# Found directory: /Users/alia/Desktop/Service Contracts Clean
# awarding_sub_agency_name
# 	FY2016.csv
# 	FY2017.csv
# 	FY2015.csv
# 	FY2014.csv
# 	FY2013.csv
# 	FY2012.csv
# 	FY2022.csv
# 	FY2020.csv
# 	FY2021.csv
# 	FY2019.csv
# 	FY2018.csv
# awarding_office_name
# 	FY2016.csv
# 	FY2017.csv
# 	FY2015.csv
# 	FY2014.csv
# 	FY2013.csv
# 	FY2012.csv
# 	FY2022.csv
# 	FY2020.csv
# 	FY2021.csv
# 	FY2019.csv
# 	FY2018.csv
# recipient_name
# 	FY2016.csv
# 	FY2017.csv
# 	FY2015.csv
# 	FY2014.csv
# 	FY2013.csv
# 	FY2012.csv
# 	FY2022.csv
# 	FY2020.csv
# 	FY2021.csv
# 	FY2019.csv
# 	FY2018.csv

# %%
def get_data(fname):
    """
    This function imports a file of longitudinal contract spending data from the Github repository for this project.
    Input: file name
    Output: Dataframe of agencies their total spending (pd.Dataframe)
    """
    url = f'https://github.com/abdelkaderalia/DoDContractApp/raw/main/Clean%20Data/Plot%20Data/{fname}.csv'
    df = pd.read_csv(url)
    return df

# %%
df_agencies = get_data('compare_agencies')
df_agencies
# Out:
#                                                 agency  fiscal_year  \
# 0                                Department of Defense         2012
# 1                                Department of Defense         2013
# 2                                Department of Defense         2014
# 3                                Department of Defense         2015
# 4                                Department of Defense         2016
# 5                                Department of Defense         2017
# 6                                Department of Defense         2018
# 7                                Department of Defense         2019
# 8                                Department of Defense         2020
# 9                                Department of Defense         2021
# 10                               Department of Defense         2022
# 11                                Department of Energy         2012
# 12                                Department of Energy         2013
# 13                                Department of Energy         2014
# 14                                Department of Energy         2015
# 15                                Department of Energy         2016
# 16                                Department of Energy         2017
# 17                                Department of Energy         2018
# 18                                Department of Energy         2019
# 19                                Department of Energy         2020
# 20                                Department of Energy         2021
# 21                                Department of Energy         2022
# 22                      Department of Veterans Affairs         2012
# 23                      Department of Veterans Affairs         2013
# 24                      Department of Veterans Affairs         2014
# 25                      Department of Veterans Affairs         2015
# 26                      Department of Veterans Affairs         2016
# 27                      Department of Veterans Affairs         2017
# 28                      Department of Veterans Affairs         2018
# 29                      Department of Veterans Affairs         2019
# 30                      Department of Veterans Affairs         2020
# 31                      Department of Veterans Affairs         2021
# 32                      Department of Veterans Affairs         2022
# 33             Department of Health and Human Services         2012
# 34             Department of Health and Human Services         2013
# 35             Department of Health and Human Services         2014
# 36             Department of Health and Human Services         2015
# 37             Department of Health and Human Services         2016
# 38             Department of Health and Human Services         2017
# 39             Department of Health and Human Services         2018
# 40             Department of Health and Human Services         2019
# 41             Department of Health and Human Services         2020
# 42             Department of Health and Human Services         2021
# 43             Department of Health and Human Services         2022
# 44                     Department of Homeland Security         2012
# 45                     Department of Homeland Security         2013
# 46                     Department of Homeland Security         2014
# 47                     Department of Homeland Security         2015
# 48                     Department of Homeland Security         2016
# 49                     Department of Homeland Security         2017
# 50                     Department of Homeland Security         2018
# 51                     Department of Homeland Security         2019
# 52                     Department of Homeland Security         2020
# 53                     Department of Homeland Security         2021
# 54                     Department of Homeland Security         2022
# 55               General Services Administration (GSA)         2012
# 56               General Services Administration (GSA)         2013
# 57               General Services Administration (GSA)         2014
# 58               General Services Administration (GSA)         2015
# 59               General Services Administration (GSA)         2016
# 60               General Services Administration (GSA)         2017
# 61               General Services Administration (GSA)         2018
# 62               General Services Administration (GSA)         2019
# 63               General Services Administration (GSA)         2020
# 64               General Services Administration (GSA)         2021
# 65               General Services Administration (GSA)         2022
# 66                                 Department of State         2012
# 67                                 Department of State         2013
# 68                                 Department of State         2014
# 69                                 Department of State         2015
# 70                                 Department of State         2016
# 71                                 Department of State         2017
# 72                                 Department of State         2018
# 73                                 Department of State         2019
# 74                                 Department of State         2020
# 75                                 Department of State         2021
# 76                                 Department of State         2022
# 77                               Department of Justice         2012
# 78                               Department of Justice         2013
# 79                               Department of Justice         2014
# 80                               Department of Justice         2015
# 81                               Department of Justice         2016
# 82                               Department of Justice         2017
# 83                               Department of Justice         2018
# 84                               Department of Justice         2019
# 85                               Department of Justice         2020
# 86                               Department of Justice         2021
# 87                               Department of Justice         2022
# 88                        Department of Transportation         2012
# 89                        Department of Transportation         2013
# 90                        Department of Transportation         2014
# 91                        Department of Transportation         2015
# 92                        Department of Transportation         2016
# 93                        Department of Transportation         2017
# 94                        Department of Transportation         2018
# 95                        Department of Transportation         2019
# 96                        Department of Transportation         2020
# 97                        Department of Transportation         2021
# 98                        Department of Transportation         2022
# 99                          Department of the Interior         2012
# 100                         Department of the Interior         2013
# 101                         Department of the Interior         2014
# 102                         Department of the Interior         2015
# 103                         Department of the Interior         2016
# 104                         Department of the Interior         2017
# 105                         Department of the Interior         2018
# 106                         Department of the Interior         2019
# 107                         Department of the Interior         2020
# 108                         Department of the Interior         2021
# 109                         Department of the Interior         2022
# 110       Agency for International Development (USAID)         2012
# 111       Agency for International Development (USAID)         2013
# 112       Agency for International Development (USAID)         2014
# 113       Agency for International Development (USAID)         2015
# 114       Agency for International Development (USAID)         2016
# 115       Agency for International Development (USAID)         2017
# 116       Agency for International Development (USAID)         2018
# 117       Agency for International Development (USAID)         2019
# 118       Agency for International Development (USAID)         2020
# 119       Agency for International Development (USAID)         2021
# 120       Agency for International Development (USAID)         2022
# 121  National Aeronautics and Space Administration ...         2012
# 122  National Aeronautics and Space Administration ...         2013
# 123  National Aeronautics and Space Administration ...         2014
# 124  National Aeronautics and Space Administration ...         2015
# 125  National Aeronautics and Space Administration ...         2016
# 126  National Aeronautics and Space Administration ...         2017
# 127  National Aeronautics and Space Administration ...         2018
# 128  National Aeronautics and Space Administration ...         2019
# 129  National Aeronautics and Space Administration ...         2020
# 130  National Aeronautics and Space Administration ...         2021
# 131  National Aeronautics and Space Administration ...         2022
#
#          spending
# 0    151413824648
# 1    132010946125
# 2    128651011788
# 3    120425333223
# 4    125523397057
# 5    132188208908
# 6    148701831637
# 7    160019506504
# 8    172578596498
# 9    160606305545
# 10   169671508880
# 11    22222846318
# 12    21324258038
# 13    23017116516
# 14    22810380007
# 15    26166592248
# 16    26829249443
# 17    29372894930
# 18    30466010323
# 19    32862930279
# 20    34446821781
# 21    37747442836
# 22     8947016285
# 23     9311749167
# 24     9943978182
# 25    10183109085
# 26    12317594245
# 27    15868388196
# 28    15873240630
# 29    17668136227
# 30    26360300103
# 31    26011250053
# 32    28053817987
# 33    11046347853
# 34    11808825805
# 35    13991346107
# 36    13834299324
# 37    15134692543
# 38    15507490112
# 39    16107784779
# 40    17038301077
# 41    10277053953
# 42    27006934979
# 43    27074889192
# 44     9095921569
# 45     8768987105
# 46     9074804750
# 47     9962003473
# 48     9661742421
# 49    11305031850
# 50    13739696947
# 51    12955257487
# 52    14112309643
# 53    15151825357
# 54    16686551913
# 55     7066181634
# 56     6266798751
# 57     6018067437
# 58     6691959250
# 59     7323217036
# 60     9701161691
# 61    10154638536
# 62    11844002900
# 63    12652188179
# 64    13434419585
# 65    15513425240
# 66     7017054235
# 67     6069949153
# 68     7861495013
# 69     6937031868
# 70     7412866377
# 71     8434892582
# 72     8619758417
# 73     8285030621
# 74     7886267543
# 75     8583571410
# 76    10242595624
# 77     4541531957
# 78     5177516197
# 79     5235775250
# 80     6691959250
# 81     5357330602
# 82     5772726749
# 83     5722276793
# 84     6341839971
# 85     6767091691
# 86     7039582764
# 87     6385418295
# 88     3922472534
# 89     3695908949
# 90     3853512018
# 91     3713405752
# 92     4362097845
# 93     4201467388
# 94     4702205580
# 95     4600647674
# 96     5558977497
# 97     5107743211
# 98     6325970936
# 99     3135986755
# 100    3063378088
# 101    3517604864
# 102    3379090184
# 103    3627804343
# 104    3612453398
# 105    3721094600
# 106    3342733518
# 107    3870016674
# 108    4470983069
# 109    5868451970
# 110    4320414831
# 111    4075092435
# 112    3566378286
# 113    4508994629
# 114    4410592246
# 115    4787210553
# 116    4764696980
# 117    5160452869
# 118    5603752157
# 119    5114193403
# 120    5453310054
# 121    4577101924
# 122    3840432350
# 123    3479709358
# 124    3610491845
# 125    3718190211
# 126    3800201953
# 127    4266999190
# 128    4283128817
# 129    3958021405
# 130    4560317299
# 131    4717229578

# %%
df = pd.read_csv('/Users/alia/Desktop/Service Contracts Clean/FY2022.csv')
df.head()
# Out:
#                         contract_award_unique_key  total_obligated_amount  \
# 0  CONT_AWD_N0018920F0208_9700_N0024418D0002_9700                27394.20
# 1       CONT_AWD_W9127S20P0051_9700_-NONE-_-NONE-                53199.50
# 2  CONT_AWD_N0042119F6075_9700_N0042117D0046_9700             45211494.89
# 3  CONT_AWD_FA561322F0102_9700_FA561321A0005_9700                 9292.44
# 4  CONT_AWD_W91QVN21F0255_9700_W91QVN18D0019_9700                38389.98
#
#   award_base_action_date         awarding_agency_name  \
# 0             2020-01-31  DEPARTMENT OF DEFENSE (DOD)
# 1             2020-03-17  DEPARTMENT OF DEFENSE (DOD)
# 2             2019-05-28  DEPARTMENT OF DEFENSE (DOD)
# 3             2022-03-15  DEPARTMENT OF DEFENSE (DOD)
# 4             2021-02-26  DEPARTMENT OF DEFENSE (DOD)
#
#   awarding_sub_agency_name                 awarding_office_name  \
# 0         DEPT OF THE NAVY           NAVSUP FLT LOG CTR NORFOLK
# 1         DEPT OF THE ARMY  US ARMY ENGINEER DISTRICT LITTLE RO
# 2         DEPT OF THE NAVY     NAVAL AIR WARFARE CENTER AIR DIV
# 3    DEPT OF THE AIR FORCE                  FA5613  700 CONS PK
# 4         DEPT OF THE ARMY  411TH CONTRACTING SUPORT BRIGAGE AU
#
#                                       recipient_name  \
# 0                                  T-MOBILE USA, INC
# 1                                     CLARK, GREGORY
# 2              SCIENCE AND ENGINEERING SERVICES, LLC
# 3  BAD GESUNDHEITSVORSORGE UND SICHERHEITSTECHNIK...
# 4                      KOREA CONTAINERPOOL CO., LTD.
#
#   primary_place_of_performance_state_code  \
# 0                                      WA
# 1                                      MO
# 2                                      AL
# 3                                     NaN
# 4                                     NaN
#
#                  product_or_service_code_description  \
# 0  IT AND TELECOM- TELECOMMUNICATIONS AND TRANSMI...
# 1  OPERATION OF RECREATION FACILITIES (NON-BUILDING)
# 2  MODIFICATION OF EQUIPMENT- AIRCRAFT COMPONENTS...
# 3                      MEDICAL- EVALUATION/SCREENING
# 4  TRANSPORTATION/TRAVEL/RELOCATION- TRANSPORTATI...
#
#   dod_claimant_program_description type_of_contract_pricing      award_type  \
# 0                         SERVICES         FIRM FIXED PRICE  DELIVERY ORDER
# 1                         SERVICES         FIRM FIXED PRICE  PURCHASE ORDER
# 2         OTHER AIRCRAFT EQUIPMENT         FIRM FIXED PRICE  DELIVERY ORDER
# 3                         SERVICES         FIRM FIXED PRICE        BPA CALL
# 4                         SERVICES         FIRM FIXED PRICE  DELIVERY ORDER
#
#   contract_bundling                     solicitation_procedures  naics_code  \
# 0       NOT BUNDLED  SUBJECT TO MULTIPLE AWARD FAIR OPPORTUNITY    517312.0
# 1       NOT BUNDLED                      SIMPLIFIED ACQUISITION    721211.0
# 2       NOT BUNDLED                   NEGOTIATED PROPOSAL/QUOTE    336411.0
# 3       NOT BUNDLED                      SIMPLIFIED ACQUISITION    621491.0
# 4       NOT BUNDLED                   NEGOTIATED PROPOSAL/QUOTE    484110.0
#
#                                    naics_description   last_modified_date
# 0  WIRELESS TELECOMMUNICATIONS CARRIERS (EXCEPT S...  2021-12-22 11:14:33
# 1    RV (RECREATIONAL VEHICLE) PARKS AND CAMPGROUNDS  2022-04-12 20:11:25
# 2                             AIRCRAFT MANUFACTURING  2022-06-21 11:59:49
# 3                                HMO MEDICAL CENTERS  2022-03-16 05:00:30
# 4                    GENERAL FREIGHT TRUCKING, LOCAL  2021-12-07 22:35:16

# %%
df_group = df.groupby(['awarding_sub_agency_name'])[['total_obligated_amount']].mean()

# Reset index
df_group = df_group.reset_index()
df_group
# Out:
#                              awarding_sub_agency_name  total_obligated_amount
# 0   DEFENSE ADVANCED RESEARCH PROJECTS AGENCY  (DA...            1.381365e+07
# 1                   DEFENSE COMMISSARY AGENCY  (DECA)            1.539611e+06
# 2           DEFENSE CONTRACT MANAGEMENT AGENCY (DCMA)            1.990306e+07
# 3     DEFENSE COUNTERINTELLIGENCE AND SECURITY AGENCY            1.322746e+07
# 4       DEFENSE FINANCE AND ACCOUNTING SERVICE (DFAS)            5.830615e+06
# 5                         DEFENSE HEALTH AGENCY (DHA)            3.263316e+07
# 6                    DEFENSE HUMAN RESOURCES ACTIVITY            3.148810e+06
# 7           DEFENSE INFORMATION SYSTEMS AGENCY (DISA)            8.290271e+05
# 8                            DEFENSE LOGISTICS AGENCY            1.320714e+06
# 9                        DEFENSE MEDIA ACTIVITY (DMA)            1.970623e+06
# 10           DEFENSE MICROELECTRONICS ACTIVITY (DMEA)            1.372068e+07
# 11             DEFENSE THREAT REDUCTION AGENCY (DTRA)            1.214932e+07
# 12         DEPT OF DEFENSE EDUCATION ACTIVITY (DODEA)            7.450260e+05
# 13                              DEPT OF THE AIR FORCE            5.251366e+06
# 14                                   DEPT OF THE ARMY            4.889385e+06
# 15                                   DEPT OF THE NAVY            2.972951e+06
# 16                       INSPECTOR GENERAL, OFFICE OF            1.625667e+04
# 17                       MISSILE DEFENSE AGENCY (MDA)            4.298449e+07
# 18                           SPACE DEVELOPMENT AGENCY            2.107322e+07
# 19                                 U.S. CYBER COMMAND            3.710391e+06
# 20          U.S. SPECIAL OPERATIONS COMMAND (USSOCOM)            4.615892e+06
# 21  UNIFORMED SERVICES UNIVERSITY OF THE HEALTH SC...            3.868736e+05
# 22                                         USTRANSCOM            2.656989e+06
# 23             WASHINGTON HEADQUARTERS SERVICES (WHS)            4.790194e+06

# %%
df_agencies = pd.read_csv('/Users/alia/Documents/Github/DoDContractApp/Clean Data/Plot Data/compare_agencies.csv')
agencies = df_agencies['agency'].unique().tolist()
agencies
# Out:
# ['Department of Defense',
#  'Department of Energy',
#  'Department of Veterans Affairs',
#  'Department of Health and Human Services',
#  'Department of Homeland Security',
#  'General Services Administration (GSA)',
#  'Department of State',
#  'Department of Justice',
#  'Department of Transportation',
#  'Department of the Interior',
#  'Agency for International Development (USAID)',
#  'National Aeronautics and Space Administration (NASA)']

# %%
agencies = sorted(agencies)
agencies.insert(0, ' ')

# %%
agencies
# Out:
# [' ',
#  'Agency for International Development (USAID)',
#  'Department of Defense',
#  'Department of Energy',
#  'Department of Health and Human Services',
#  'Department of Homeland Security',
#  'Department of Justice',
#  'Department of State',
#  'Department of Transportation',
#  'Department of Veterans Affairs',
#  'Department of the Interior',
#  'General Services Administration (GSA)',
#  'National Aeronautics and Space Administration (NASA)']

# %%
sub_col_names = {'Awarding Subagency':'awarding_sub_agency_name','Awarding Office':'awarding_office_name','Contract Recipient':'recipient_name'}
sub_col_names['Awarding Subagency']
# Out:
# 'awarding_sub_agency_name'

# %%
test22 = pd.read_csv('/Users/alia/Desktop/Service Contracts Raw/FY2022.csv')
test22.head()
# Out:
#                         contract_award_unique_key  award_id_piid  \
# 0  CONT_AWD_N0018920F0208_9700_N0024418D0002_9700  N0018920F0208
# 1       CONT_AWD_W9127S20P0051_9700_-NONE-_-NONE-  W9127S20P0051
# 2  CONT_AWD_N0042119F6075_9700_N0042117D0046_9700  N0042119F6075
# 3  CONT_AWD_FA561322F0102_9700_FA561321A0005_9700  FA561322F0102
# 4  CONT_AWD_W91QVN21F0255_9700_W91QVN18D0019_9700  W91QVN21F0255
#
#    parent_award_agency_id parent_award_agency_name parent_award_id_piid  \
# 0                  9700.0          DEPT OF DEFENSE        N0024418D0002
# 1                     NaN                      NaN                  NaN
# 2                  9700.0          DEPT OF DEFENSE        N0042117D0046
# 3                  9700.0          DEPT OF DEFENSE        FA561321A0005
# 4                  9700.0          DEPT OF DEFENSE        W91QVN18D0019
#
#                        disaster_emergency_fund_codes  \
# 0  Q: Excluded from tracking (uses non-emergency/...
# 1  Q: Excluded from tracking (uses non-emergency/...
# 2                                                NaN
# 3  Q: Excluded from tracking (uses non-emergency/...
# 4  Q: Excluded from tracking (uses non-emergency/...
#
#    outlayed_amount_funded_by_COVID-19_supplementals  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#    obligated_amount_funded_by_COVID-19_supplementals  total_obligated_amount  \
# 0                                                NaN                27394.20
# 1                                                NaN                53199.50
# 2                                                NaN             45211494.89
# 3                                                NaN                 9292.44
# 4                                                NaN                38389.98
#
#    current_total_value_of_award  potential_total_value_of_award  \
# 0                      27394.20                        27394.20
# 1                      53199.50                        53199.50
# 2                   45211494.89                     45511494.89
# 3                       9292.44                         9292.44
# 4                      38389.98                        38389.98
#
#   award_base_action_date  award_base_action_date_fiscal_year  \
# 0             2020-01-31                                2020
# 1             2020-03-17                                2020
# 2             2019-05-28                                2019
# 3             2022-03-15                                2022
# 4             2021-02-26                                2021
#
#   award_latest_action_date  award_latest_action_date_fiscal_year  \
# 0               2021-12-22                                  2022
# 1               2022-04-12                                  2022
# 2               2022-06-21                                  2022
# 3               2022-03-15                                  2022
# 4               2021-12-07                                  2022
#
#   period_of_performance_start_date period_of_performance_current_end_date  \
# 0                       2020-02-10                    2023-02-09 00:00:00
# 1                       2020-03-17                    2023-02-28 00:00:00
# 2                       2019-05-28                    2022-09-30 00:00:00
# 3                       2022-01-01                    2022-01-31 00:00:00
# 4                       2021-02-26                    2021-05-31 00:00:00
#
#   period_of_performance_potential_end_date  ordering_period_end_date  \
# 0                      2023-02-09 00:00:00                       NaN
# 1                      2023-02-28 00:00:00                       NaN
# 2                      2023-05-27 00:00:00                       NaN
# 3                      2022-01-31 00:00:00                       NaN
# 4                      2021-05-31 00:00:00                       NaN
#
#   solicitation_date  awarding_agency_code         awarding_agency_name  \
# 0               NaN                    97  DEPARTMENT OF DEFENSE (DOD)
# 1               NaN                    97  DEPARTMENT OF DEFENSE (DOD)
# 2        2019-02-05                    97  DEPARTMENT OF DEFENSE (DOD)
# 3               NaN                    97  DEPARTMENT OF DEFENSE (DOD)
# 4               NaN                    97  DEPARTMENT OF DEFENSE (DOD)
#
#   awarding_sub_agency_code awarding_sub_agency_name awarding_office_code  \
# 0                     1700         DEPT OF THE NAVY               N00189
# 1                     2100         DEPT OF THE ARMY               W9127S
# 2                     1700         DEPT OF THE NAVY               N00421
# 3                     5700    DEPT OF THE AIR FORCE               FA5613
# 4                     2100         DEPT OF THE ARMY               W91QVN
#
#                   awarding_office_name  funding_agency_code  \
# 0           NAVSUP FLT LOG CTR NORFOLK                   97
# 1  US ARMY ENGINEER DISTRICT LITTLE RO                   97
# 2     NAVAL AIR WARFARE CENTER AIR DIV                   97
# 3                  FA5613  700 CONS PK                   97
# 4  411TH CONTRACTING SUPORT BRIGAGE AU                   97
#
#            funding_agency_name funding_sub_agency_code  \
# 0  DEPARTMENT OF DEFENSE (DOD)                    1700
# 1  DEPARTMENT OF DEFENSE (DOD)                    2100
# 2  DEPARTMENT OF DEFENSE (DOD)                    1700
# 3  DEPARTMENT OF DEFENSE (DOD)                    5700
# 4  DEPARTMENT OF DEFENSE (DOD)                    2100
#
#   funding_sub_agency_name funding_office_code  \
# 0        DEPT OF THE NAVY              N46581
# 1        DEPT OF THE ARMY              W9127S
# 2        DEPT OF THE NAVY              N00421
# 3   DEPT OF THE AIR FORCE              F3N056
# 4        DEPT OF THE ARMY              W582MZ
#
#                    funding_office_name  \
# 0        NAVAL SURFACE FORCE USLANTFLT
# 1  US ARMY ENGINEER DISTRICT LITTLE RO
# 2     NAVAL AIR WARFARE CENTER AIR DIV
# 3                 F3N056 86 MDG AF BPN
# 4        HHC, 19TH SUSTAINMENT COMMAND
#
#             treasury_accounts_funding_this_award  \
# 0  017-2020/2020-1804-000;017-2021/2021-1804-000
# 1                                 096-X-3123-000
# 2                                            NaN
# 3                         057-2022/2022-3400-000
# 4                         021-2021/2021-2020-000
#
#   federal_accounts_funding_this_award  \
# 0                            017-1804
# 1                            096-3123
# 2                                 NaN
# 3                            057-3400
# 4                            021-2020
#
#                    object_classes_funding_this_award  \
# 0  23.3: Communications, utilities, and miscellan...
# 1  25.2: Other services from non-Federal sources;...
# 2                                                NaN
# 3                                 25.6: Medical care
# 4                     22.0: Transportation of things
#
#    program_activities_funding_this_award foreign_funding  \
# 0                 0001: OPERATING FORCES               X
# 1  0005: MULTIPURPOSE AND OTHER PROGRAMS               X
# 2                                    NaN               A
# 3                 0001: OPERATING FORCES               X
# 4                 0001: OPERATING FORCES               X
#
#   foreign_funding_description  sam_exception sam_exception_description  \
# 0              NOT APPLICABLE            NaN                       NaN
# 1              NOT APPLICABLE            NaN                       NaN
# 2           FOREIGN FUNDS FMS            NaN                       NaN
# 3              NOT APPLICABLE            NaN                       NaN
# 4              NOT APPLICABLE            NaN                       NaN
#
#   recipient_uei  recipient_duns  \
# 0  ZVW2T2CCG7V9      68528376.0
# 1  L3VSZXZKNH83             NaN
# 2  E3D7U1KNNJC8             NaN
# 3  RK5ABYN4VD75             NaN
# 4  ZMJUSTAC4NC6     631094562.0
#
#                                       recipient_name  \
# 0                                  T-MOBILE USA, INC
# 1                                     CLARK, GREGORY
# 2              SCIENCE AND ENGINEERING SERVICES, LLC
# 3  BAD GESUNDHEITSVORSORGE UND SICHERHEITSTECHNIK...
# 4                      KOREA CONTAINERPOOL CO., LTD.
#
#   recipient_doing_business_as_name cage_code recipient_parent_uei  \
# 0                              NaN     3BQL1         U5KEFDV4N965
# 1                              NaN     8BWD8         L3VSZXZKNH83
# 2                              NaN     4Q232         Y7SKZ1CJ5TD1
# 3                              NaN     DB513         RK4TY58W95T8
# 4                              NaN     269EF         ZMJUSTAC4NC6
#
#    recipient_parent_duns                              recipient_parent_name  \
# 0            145373945.0                                 T-MOBILE USA  INC.
# 1                    NaN                                     CLARK  GREGORY
# 2                    NaN             SCIENCE AND ENGINEERING SERVICES  INC.
# 3                    NaN  BERUFSGENOSSENSCHAFTLICHER ARBEITSMEDIZINISCHE...
# 4            631094562.0                      KOREA CONTAINERPOOL CO.  LTD.
#
#   recipient_country_code recipient_country_name  recipient_address_line_1  \
# 0                    USA          UNITED STATES   12920 SOUTHEAST 38TH ST
# 1                    USA          UNITED STATES      929 E US HIGHWAY 160
# 2                    USA          UNITED STATES           248 DUNLOP BLVD
# 3                    DEU                GERMANY     HERBERT-RABIUS-STR. 1
# 4                    KOR           KOREA, SOUTH  63-8 MAPO-DAERO, MAPO-GU
#
#   recipient_address_line_2 recipient_city_name recipient_county_name  \
# 0                      NaN            BELLEVUE                  KING
# 1                      NaN               LAMAR                BARTON
# 2                      NaN          HUNTSVILLE               MADISON
# 3                      NaN                BONN                   NaN
# 4                      NaN               SEOUL                   NaN
#
#   recipient_state_code recipient_state_name recipient_zip_4_code  \
# 0                   WA           WASHINGTON            980061350
# 1                   MO             MISSOURI            647598231
# 2                   AL              ALABAMA            358241102
# 3                  NaN                  NaN                53225
# 4                  NaN                SEOUL                04157
#
#    recipient_congressional_district recipient_phone_number  \
# 0                               9.0             7209982153
# 1                               4.0             4172623251
# 2                               5.0             2562580500
# 3                               NaN                    NaN
# 4                               NaN                    NaN
#
#   recipient_fax_number primary_place_of_performance_country_code  \
# 0         3033677010.0                                       USA
# 1                  NaN                                       USA
# 2         2568583830.0                                       USA
# 3         2284007218.0                                       DEU
# 4                  NaN                                       KOR
#
#   primary_place_of_performance_country_name  \
# 0                             UNITED STATES
# 1                             UNITED STATES
# 2                             UNITED STATES
# 3                                   GERMANY
# 4                              KOREA, SOUTH
#
#   primary_place_of_performance_city_name  \
# 0                               BELLEVUE
# 1                                BRANSON
# 2                             HUNTSVILLE
# 3                                    NaN
# 4                                    NaN
#
#   primary_place_of_performance_county_name  \
# 0                                     KING
# 1                                    TANEY
# 2                                  MADISON
# 3                                      NaN
# 4                                      NaN
#
#   primary_place_of_performance_state_code  \
# 0                                      WA
# 1                                      MO
# 2                                      AL
# 3                                     NaN
# 4                                     NaN
#
#   primary_place_of_performance_state_name primary_place_of_performance_zip_4  \
# 0                              WASHINGTON                          980061350
# 1                                MISSOURI                          656162418
# 2                                 ALABAMA                          358241102
# 3                                     NaN                                NaN
# 4                                     NaN                                NaN
#
#    primary_place_of_performance_congressional_district award_or_idv_flag  \
# 0                                                9.0               AWARD
# 1                                                7.0               AWARD
# 2                                                5.0               AWARD
# 3                                                NaN               AWARD
# 4                                                NaN               AWARD
#
#   award_type_code      award_type  idv_type_code  idv_type  \
# 0               C  DELIVERY ORDER            NaN       NaN
# 1               B  PURCHASE ORDER            NaN       NaN
# 2               C  DELIVERY ORDER            NaN       NaN
# 3               A        BPA CALL            NaN       NaN
# 4               C  DELIVERY ORDER            NaN       NaN
#
#    multiple_or_single_award_idv_code  multiple_or_single_award_idv  \
# 0                                NaN                           NaN
# 1                                NaN                           NaN
# 2                                NaN                           NaN
# 3                                NaN                           NaN
# 4                                NaN                           NaN
#
#    type_of_idc_code  type_of_idc type_of_contract_pricing_code  \
# 0               NaN          NaN                             J
# 1               NaN          NaN                             J
# 2               NaN          NaN                             J
# 3               NaN          NaN                             J
# 4               NaN          NaN                             J
#
#   type_of_contract_pricing           prime_award_base_transaction_description  \
# 0         FIRM FIXED PRICE                                  WIRELESS SERVICES
# 1         FIRM FIXED PRICE                       CAPE FAIR CLEANING ATTENDANT
# 2         FIRM FIXED PRICE  IGF::OT::IGF MALAYSIAN CN-235 INTELLIGENCE, SU...
# 3         FIRM FIXED PRICE      BPA CALLS 1 - 31 JANUARY 2022 TOTAL AMOUNT: 9
# 4         FIRM FIXED PRICE        VAN TRUCKING SVCS FOR DECA (CLIN 2033-2043)
#
#   solicitation_identifier  number_of_actions  \
# 0           N0018920Q0064                  1
# 1           W9127S20Q0012                  1
# 2           N0042116R0040                  1
# 3                     NaN                  1
# 4           W91QVN17R0118                  1
#
#   inherently_governmental_functions  \
# 0                                OT
# 1                                OT
# 2                                OT
# 3                                OT
# 4                                OT
#
#   inherently_governmental_functions_description product_or_service_code  \
# 0                               OTHER FUNCTIONS                    D304
# 1                               OTHER FUNCTIONS                    M1PA
# 2                               OTHER FUNCTIONS                    K016
# 3                               OTHER FUNCTIONS                    Q403
# 4                               OTHER FUNCTIONS                    V119
#
#                  product_or_service_code_description contract_bundling_code  \
# 0  IT AND TELECOM- TELECOMMUNICATIONS AND TRANSMI...                      H
# 1  OPERATION OF RECREATION FACILITIES (NON-BUILDING)                      H
# 2  MODIFICATION OF EQUIPMENT- AIRCRAFT COMPONENTS...                      H
# 3                      MEDICAL- EVALUATION/SCREENING                      H
# 4  TRANSPORTATION/TRAVEL/RELOCATION- TRANSPORTATI...                      H
#
#   contract_bundling dod_claimant_program_code  \
# 0       NOT BUNDLED                        S1
# 1       NOT BUNDLED                        S1
# 2       NOT BUNDLED                       A1C
# 3       NOT BUNDLED                        S1
# 4       NOT BUNDLED                        S1
#
#   dod_claimant_program_description  naics_code  \
# 0                         SERVICES    517312.0
# 1                         SERVICES    721211.0
# 2         OTHER AIRCRAFT EQUIPMENT    336411.0
# 3                         SERVICES    621491.0
# 4                         SERVICES    484110.0
#
#                                    naics_description  \
# 0  WIRELESS TELECOMMUNICATIONS CARRIERS (EXCEPT S...
# 1    RV (RECREATIONAL VEHICLE) PARKS AND CAMPGROUNDS
# 2                             AIRCRAFT MANUFACTURING
# 3                                HMO MEDICAL CENTERS
# 4                    GENERAL FREIGHT TRUCKING, LOCAL
#
#   recovered_materials_sustainability_code  \
# 0                                       C
# 1                                       I
# 2                                       C
# 3                                       C
# 4                                       C
#
#                   recovered_materials_sustainability  \
# 0  NO CLAUSES INCLUDED AND NO SUSTAINABILITY INCL...
# 1          FAR 52.223-4 & ENVIRONMENTALLY PREFERABLE
# 2  NO CLAUSES INCLUDED AND NO SUSTAINABILITY INCL...
# 3  NO CLAUSES INCLUDED AND NO SUSTAINABILITY INCL...
# 4  NO CLAUSES INCLUDED AND NO SUSTAINABILITY INCL...
#
#   domestic_or_foreign_entity_code  \
# 0                               A
# 1                               A
# 2                               A
# 3                               D
# 4                               D
#
#                           domestic_or_foreign_entity  \
# 0                                U.S. OWNED BUSINESS
# 1                                U.S. OWNED BUSINESS
# 2                                U.S. OWNED BUSINESS
# 3  FOREIGN-OWNED BUSINESS NOT INCORPORATED IN THE...
# 4  FOREIGN-OWNED BUSINESS NOT INCORPORATED IN THE...
#
#   dod_acquisition_program_code dod_acquisition_program_description  \
# 0                          000                                NONE
# 1                          000                                NONE
# 2                          000                                NONE
# 3                          000                                NONE
# 4                          000                                NONE
#
#   information_technology_commercial_item_category_code  \
# 0                                                  A
# 1                                                  Z
# 2                                                  Z
# 3                                                  Z
# 4                                                  Z
#
#   information_technology_commercial_item_category epa_designated_product_code  \
# 0                          COMMERCIALLY AVAILABLE                           E
# 1                     NOT IT PRODUCTS OR SERVICES                           A
# 2                     NOT IT PRODUCTS OR SERVICES                           A
# 3                     NOT IT PRODUCTS OR SERVICES                           E
# 4                     NOT IT PRODUCTS OR SERVICES                           E
#
#   epa_designated_product country_of_product_or_service_origin_code  \
# 0           NOT REQUIRED                                       USA
# 1     MEETS REQUIREMENTS                                       USA
# 2     MEETS REQUIREMENTS                                       USA
# 3           NOT REQUIRED                                       DEU
# 4           NOT REQUIRED                                       KOR
#
#   country_of_product_or_service_origin place_of_manufacture_code  \
# 0                        UNITED STATES                         C
# 1                        UNITED STATES                         C
# 2                        UNITED STATES                         C
# 3                              GERMANY                         C
# 4                         KOREA, SOUTH                         C
#
#              place_of_manufacture subcontracting_plan_code  \
# 0  NOT A MANUFACTURED END PRODUCT                        F
# 1  NOT A MANUFACTURED END PRODUCT                        B
# 2  NOT A MANUFACTURED END PRODUCT                        B
# 3  NOT A MANUFACTURED END PRODUCT                        B
# 4  NOT A MANUFACTURED END PRODUCT                        B
#
#            subcontracting_plan extent_competed_code  \
# 0  INDIVIDUAL SUBCONTRACT PLAN                    A
# 1            PLAN NOT REQUIRED                    F
# 2            PLAN NOT REQUIRED                    A
# 3            PLAN NOT REQUIRED                    F
# 4            PLAN NOT REQUIRED                    A
#
#              extent_competed solicitation_procedures_code  \
# 0  FULL AND OPEN COMPETITION                         MAFO
# 1         COMPETED UNDER SAP                          SP1
# 2  FULL AND OPEN COMPETITION                           NP
# 3         COMPETED UNDER SAP                          SP1
# 4  FULL AND OPEN COMPETITION                           NP
#
#                       solicitation_procedures type_of_set_aside_code  \
# 0  SUBJECT TO MULTIPLE AWARD FAIR OPPORTUNITY                    NaN
# 1                      SIMPLIFIED ACQUISITION                    SBA
# 2                   NEGOTIATED PROPOSAL/QUOTE                    NaN
# 3                      SIMPLIFIED ACQUISITION                   NONE
# 4                   NEGOTIATED PROPOSAL/QUOTE                    NaN
#
#                   type_of_set_aside evaluated_preference_code  \
# 0                               NaN                      NONE
# 1  SMALL BUSINESS SET ASIDE - TOTAL                      NONE
# 2                               NaN                      NONE
# 3                NO SET ASIDE USED.                      NONE
# 4                               NaN                      NONE
#
#   evaluated_preference research_code research  \
# 0   NO PREFERENCE USED           NaN      NaN
# 1   NO PREFERENCE USED           NaN      NaN
# 2   NO PREFERENCE USED           NaN      NaN
# 3   NO PREFERENCE USED           NaN      NaN
# 4   NO PREFERENCE USED           NaN      NaN
#
#   fair_opportunity_limited_sources_code fair_opportunity_limited_sources  \
# 0                                  FAIR           FAIR OPPORTUNITY GIVEN
# 1                                   NaN                              NaN
# 2                                   NaN                              NaN
# 3                                   NaN                              NaN
# 4                                   NaN                              NaN
#
#   other_than_full_and_open_competition_code  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   other_than_full_and_open_competition  number_of_offers_received  \
# 0                                  NaN                        3.0
# 1                                  NaN                        4.0
# 2                                  NaN                        NaN
# 3                                  NaN                        1.0
# 4                                  NaN                        NaN
#
#   commercial_item_acquisition_procedures_code  \
# 0                                           A
# 1                                           A
# 2                                           D
# 3                                           A
# 4                                           A
#
#              commercial_item_acquisition_procedures  \
# 0                                   COMMERCIAL ITEM
# 1                                   COMMERCIAL ITEM
# 2  COMMERCIAL PRODUCTS/SERVICES PROCEDURES NOT USED
# 3                                   COMMERCIAL ITEM
# 4                                   COMMERCIAL ITEM
#
#   small_business_competitiveness_demonstration_program  \
# 0                                                  f
# 1                                                  f
# 2                                                  f
# 3                                                  f
# 4                                                  f
#
#   simplified_procedures_for_certain_commercial_items_code  \
# 0                                                  N
# 1                                                  N
# 2                                                  N
# 3                                                  N
# 4                                                  N
#
#   simplified_procedures_for_certain_commercial_items a76_fair_act_action_code  \
# 0                                                 NO                        N
# 1                                                 NO                        N
# 2                                                 NO                        N
# 3                                                 NO                        N
# 4                                                 NO                        N
#
#   a76_fair_act_action fed_biz_opps_code    fed_biz_opps  \
# 0                  NO                 Y             YES
# 1                  NO                 X  NOT APPLICABLE
# 2                  NO                 X  NOT APPLICABLE
# 3                  NO                 N              NO
# 4                  NO                 X  NOT APPLICABLE
#
#   local_area_set_aside_code local_area_set_aside  \
# 0                         N                   NO
# 1                         N                   NO
# 2                         N                   NO
# 3                         N                   NO
# 4                         N                   NO
#
#    price_evaluation_adjustment_preference_percent_difference  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   clinger_cohen_act_planning_code clinger_cohen_act_planning  \
# 0                               N                         NO
# 1                               N                         NO
# 2                               N                         NO
# 3                               N                         NO
# 4                               N                         NO
#
#   materials_supplies_articles_equipment_code  \
# 0                                          N
# 1                                          X
# 2                                          Y
# 3                                          X
# 4                                          X
#
#   materials_supplies_articles_equipment labor_standards_code labor_standards  \
# 0                                    NO                    N              NO
# 1                        NOT APPLICABLE                    Y             YES
# 2                                   YES                    Y             YES
# 3                        NOT APPLICABLE                    X  NOT APPLICABLE
# 4                        NOT APPLICABLE                    X  NOT APPLICABLE
#
#   construction_wage_rate_requirements_code  \
# 0                                        N
# 1                                        Y
# 2                                        N
# 3                                        X
# 4                                        X
#
#   construction_wage_rate_requirements interagency_contracting_authority_code  \
# 0                                  NO                                      X
# 1                                 YES                                      X
# 2                                  NO                                      X
# 3                      NOT APPLICABLE                                      X
# 4                      NOT APPLICABLE                                      X
#
#   interagency_contracting_authority other_statutory_authority  \
# 0                    NOT APPLICABLE                       NaN
# 1                    NOT APPLICABLE                       NaN
# 2                    NOT APPLICABLE                       NaN
# 3                    NOT APPLICABLE                       NaN
# 4                    NOT APPLICABLE                       NaN
#
#    program_acronym parent_award_type_code parent_award_type  \
# 0              NaN                      B               IDC
# 1              NaN                    NaN               NaN
# 2              NaN                      B               IDC
# 3              NaN                      E               BPA
# 4              NaN                      B               IDC
#
#   parent_award_single_or_multiple_code parent_award_single_or_multiple  \
# 0                                    M                  MULTIPLE AWARD
# 1                                  NaN                             NaN
# 2                                    S                    SINGLE AWARD
# 3                                    S                    SINGLE AWARD
# 4                                    S                    SINGLE AWARD
#
#   major_program national_interest_action_code national_interest_action  \
# 0           NaN                          NONE                     NONE
# 1           NaN                          NONE                     NONE
# 2           NaN                          NONE                     NONE
# 3           NaN                          NONE                     NONE
# 4           NaN                          NONE                     NONE
#
#   cost_or_pricing_data_code cost_or_pricing_data  \
# 0                         N                   NO
# 1                       NaN                  NaN
# 2                         N                   NO
# 3                         N                   NO
# 4                         N                   NO
#
#   cost_accounting_standards_clause_code cost_accounting_standards_clause  \
# 0                                   NaN                              NaN
# 1                                   NaN                              NaN
# 2                                   NaN                              NaN
# 3                                   NaN                              NaN
# 4                                   NaN                              NaN
#
#   government_furnished_property_code government_furnished_property  \
# 0                                  N                             N
# 1                                  N                             N
# 2                                  N                             N
# 3                                  N                             N
# 4                                  N                             N
#
#   sea_transportation_code sea_transportation consolidated_contract_code  \
# 0                       N                 NO                          D
# 1                       U            UNKNOWN                          D
# 2                       N                 NO                          D
# 3                       N                 NO                          D
# 4                       U            UNKNOWN                          D
#
#   consolidated_contract performance_based_service_acquisition_code  \
# 0      NOT CONSOLIDATED                                          Y
# 1      NOT CONSOLIDATED                                          Y
# 2      NOT CONSOLIDATED                                          N
# 3      NOT CONSOLIDATED                                          Y
# 4      NOT CONSOLIDATED                                          Y
#
#   performance_based_service_acquisition multi_year_contract_code  \
# 0      YES - SERVICE WHERE PBA IS USED.                        N
# 1      YES - SERVICE WHERE PBA IS USED.                      NaN
# 2   NO - SERVICE WHERE PBA IS NOT USED.                        Y
# 3      YES - SERVICE WHERE PBA IS USED.                      NaN
# 4      YES - SERVICE WHERE PBA IS USED.                        N
#
#   multi_year_contract contract_financing_code  \
# 0                  NO                       Z
# 1                 NaN                       Z
# 2                 YES                       D
# 3                 NaN                       Z
# 4                  NO                       Z
#
#                               contract_financing  \
# 0                                 NOT APPLICABLE
# 1                                 NOT APPLICABLE
# 2  UNUSUAL PROGRESS PAYMENTS OR ADVANCE PAYMENTS
# 3                                 NOT APPLICABLE
# 4                                 NOT APPLICABLE
#
#   purchase_card_as_payment_method_code purchase_card_as_payment_method  \
# 0                                    N                              NO
# 1                                    N                              NO
# 2                                    N                              NO
# 3                                    N                              NO
# 4                                    N                              NO
#
#   contingency_humanitarian_or_peacekeeping_operation_code  \
# 0                                                  X
# 1                                                  X
# 2                                                  X
# 3                                                  X
# 4                                                  X
#
#   contingency_humanitarian_or_peacekeeping_operation  \
# 0                                     NOT APPLICABLE
# 1                                     NOT APPLICABLE
# 2                                     NOT APPLICABLE
# 3                                     NOT APPLICABLE
# 4                                     NOT APPLICABLE
#
#   alaskan_native_corporation_owned_firm american_indian_owned_business  \
# 0                                     f                              f
# 1                                     f                              f
# 2                                     f                              f
# 3                                     f                              f
# 4                                     f                              f
#
#   indian_tribe_federally_recognized native_hawaiian_organization_owned_firm  \
# 0                                 f                                       f
# 1                                 f                                       f
# 2                                 f                                       f
# 3                                 f                                       f
# 4                                 f                                       f
#
#   tribally_owned_firm veteran_owned_business  \
# 0                   f                      f
# 1                   f                      f
# 2                   f                      f
# 3                   f                      f
# 4                   f                      f
#
#   service_disabled_veteran_owned_business woman_owned_business  \
# 0                                       f                    f
# 1                                       f                    f
# 2                                       f                    f
# 3                                       f                    f
# 4                                       f                    f
#
#   women_owned_small_business  \
# 0                          f
# 1                          f
# 2                          f
# 3                          f
# 4                          f
#
#   economically_disadvantaged_women_owned_small_business  \
# 0                                                  f
# 1                                                  f
# 2                                                  f
# 3                                                  f
# 4                                                  f
#
#   joint_venture_women_owned_small_business  \
# 0                                        f
# 1                                        f
# 2                                        f
# 3                                        f
# 4                                        f
#
#   joint_venture_economic_disadvantaged_women_owned_small_bus  \
# 0                                                  f
# 1                                                  f
# 2                                                  f
# 3                                                  f
# 4                                                  f
#
#   minority_owned_business  \
# 0                       f
# 1                       f
# 2                       t
# 3                       f
# 4                       t
#
#   subcontinent_asian_asian_indian_american_owned_business  \
# 0                                                  f
# 1                                                  f
# 2                                                  f
# 3                                                  f
# 4                                                  f
#
#   asian_pacific_american_owned_business black_american_owned_business  \
# 0                                     f                             f
# 1                                     f                             f
# 2                                     t                             f
# 3                                     f                             f
# 4                                     t                             f
#
#   hispanic_american_owned_business native_american_owned_business  \
# 0                                f                              f
# 1                                f                              f
# 2                                f                              f
# 3                                f                              f
# 4                                f                              f
#
#   other_minority_owned_business  \
# 0                             f
# 1                             f
# 2                             f
# 3                             f
# 4                             f
#
#   contracting_officers_determination_of_business_size  \
# 0                          OTHER THAN SMALL BUSINESS
# 1                                     SMALL BUSINESS
# 2                          OTHER THAN SMALL BUSINESS
# 3                          OTHER THAN SMALL BUSINESS
# 4                          OTHER THAN SMALL BUSINESS
#
#   contracting_officers_determination_of_business_size_code  \
# 0                                                  O
# 1                                                  S
# 2                                                  O
# 3                                                  O
# 4                                                  O
#
#   emerging_small_business community_developed_corporation_owned_firm  \
# 0                       f                                          f
# 1                       f                                          f
# 2                       f                                          f
# 3                       f                                          f
# 4                       f                                          f
#
#   labor_surplus_area_firm us_federal_government  \
# 0                       f                     f
# 1                       f                     f
# 2                       f                     f
# 3                       f                     f
# 4                       f                     f
#
#   federally_funded_research_and_development_corp federal_agency  \
# 0                                              f              f
# 1                                              f              f
# 2                                              f              f
# 3                                              f              f
# 4                                              f              f
#
#   us_state_government us_local_government city_local_government  \
# 0                   f                   f                     f
# 1                   f                   f                     f
# 2                   f                   f                     f
# 3                   f                   f                     f
# 4                   f                   f                     f
#
#   county_local_government inter_municipal_local_government  \
# 0                       f                                f
# 1                       f                                f
# 2                       f                                f
# 3                       f                                f
# 4                       f                                f
#
#   local_government_owned municipality_local_government  \
# 0                      f                             f
# 1                      f                             f
# 2                      f                             f
# 3                      f                             f
# 4                      f                             f
#
#   school_district_local_government township_local_government  \
# 0                                f                         f
# 1                                f                         f
# 2                                f                         f
# 3                                f                         f
# 4                                f                         f
#
#   us_tribal_government foreign_government       organizational_type  \
# 0                    f                  f  CORPORATE NOT TAX EXEMPT
# 1                    f                  f       SOLE PROPRIETORSHIP
# 2                    f                  f                     OTHER
# 3                    f                  f                     OTHER
# 4                    f                  f  CORPORATE NOT TAX EXEMPT
#
#   corporate_entity_not_tax_exempt corporate_entity_tax_exempt  \
# 0                               t                           f
# 1                               f                           f
# 2                               f                           f
# 3                               f                           f
# 4                               t                           f
#
#   partnership_or_limited_liability_partnership sole_proprietorship  \
# 0                                            f                   f
# 1                                            f                   t
# 2                                            f                   f
# 3                                            f                   f
# 4                                            f                   f
#
#   small_agricultural_cooperative international_organization  \
# 0                              f                          f
# 1                              f                          f
# 2                              f                          f
# 3                              f                          f
# 4                              f                          f
#
#   us_government_entity community_development_corporation domestic_shelter  \
# 0                    f                                 f                f
# 1                    f                                 f                f
# 2                    f                                 f                f
# 3                    f                                 f                f
# 4                    f                                 f                f
#
#   educational_institution foundation hospital_flag manufacturer_of_goods  \
# 0                       f          f             f                     f
# 1                       f          f             f                     f
# 2                       f          f             f                     f
# 3                       f          f             f                     f
# 4                       f          f             f                     f
#
#   veterinary_hospital hispanic_servicing_institution receives_contracts  \
# 0                   f                              f                  f
# 1                   f                              f                  f
# 2                   f                              f                  f
# 3                   f                              f                  f
# 4                   f                              f                  f
#
#   receives_financial_assistance receives_contracts_and_financial_assistance  \
# 0                             f                                           t
# 1                             f                                           t
# 2                             f                                           f
# 3                             f                                           t
# 4                             f                                           t
#
#   airport_authority council_of_governments housing_authorities_public_tribal  \
# 0                 f                      f                                 f
# 1                 f                      f                                 f
# 2                 f                      f                                 f
# 3                 f                      f                                 f
# 4                 f                      f                                 f
#
#   interstate_entity planning_commission port_authority transit_authority  \
# 0                 f                   f              f                 f
# 1                 f                   f              f                 f
# 2                 f                   f              f                 f
# 3                 f                   f              f                 f
# 4                 f                   f              f                 f
#
#   subchapter_scorporation limited_liability_corporation foreign_owned  \
# 0                       f                             f             f
# 1                       f                             f             f
# 2                       f                             t             f
# 3                       f                             f             f
# 4                       f                             f             f
#
#   for_profit_organization nonprofit_organization  \
# 0                       t                      f
# 1                       t                      f
# 2                       t                      f
# 3                       t                      f
# 4                       t                      f
#
#   other_not_for_profit_organization the_ability_one_program  \
# 0                                 f                       f
# 1                                 f                       f
# 2                                 f                       f
# 3                                 f                       f
# 4                                 f                       f
#
#   private_university_or_college  \
# 0                             f
# 1                             f
# 2                             f
# 3                             f
# 4                             f
#
#   state_controlled_institution_of_higher_learning 1862_land_grant_college  \
# 0                                               f                       f
# 1                                               f                       f
# 2                                               f                       f
# 3                                               f                       f
# 4                                               f                       f
#
#   1890_land_grant_college 1994_land_grant_college minority_institution  \
# 0                       f                       f                    f
# 1                       f                       f                    f
# 2                       f                       f                    f
# 3                       f                       f                    f
# 4                       f                       f                    f
#
#   historically_black_college tribal_college  \
# 0                          f              f
# 1                          f              f
# 2                          f              f
# 3                          f              f
# 4                          f              f
#
#   alaskan_native_servicing_institution native_hawaiian_servicing_institution  \
# 0                                    f                                     f
# 1                                    f                                     f
# 2                                    f                                     f
# 3                                    f                                     f
# 4                                    f                                     f
#
#   school_of_forestry veterinary_college dot_certified_disadvantage  \
# 0                  f                  f                          f
# 1                  f                  f                          f
# 2                  f                  f                          f
# 3                  f                  f                          f
# 4                  f                  f                          f
#
#   self_certified_small_disadvantaged_business small_disadvantaged_business  \
# 0                                           f                            f
# 1                                           f                            f
# 2                                           f                            f
# 3                                           f                            f
# 4                                           f                            f
#
#   c8a_program_participant  \
# 0                       f
# 1                       f
# 2                       f
# 3                       f
# 4                       f
#
#   historically_underutilized_business_zone_hubzone_firm  \
# 0                                                  f
# 1                                                  f
# 2                                                  f
# 3                                                  f
# 4                                                  f
#
#   sba_certified_8a_joint_venture highly_compensated_officer_1_name  \
# 0                              f                               NaN
# 1                              f                               NaN
# 2                              f                         HYO S LEE
# 3                              f                               NaN
# 4                              f                               NaN
#
#    highly_compensated_officer_1_amount highly_compensated_officer_2_name  \
# 0                                  NaN                               NaN
# 1                                  NaN                               NaN
# 2                             350000.0                 EDWARD J SINCLAIR
# 3                                  NaN                               NaN
# 4                                  NaN                               NaN
#
#    highly_compensated_officer_2_amount highly_compensated_officer_3_name  \
# 0                                  NaN                               NaN
# 1                                  NaN                               NaN
# 2                             346834.0                  RALPH G PALLOTTA
# 3                                  NaN                               NaN
# 4                                  NaN                               NaN
#
#    highly_compensated_officer_3_amount highly_compensated_officer_4_name  \
# 0                                  NaN                               NaN
# 1                                  NaN                               NaN
# 2                             325814.0                     BRAD J KILLEN
# 3                                  NaN                               NaN
# 4                                  NaN                               NaN
#
#    highly_compensated_officer_4_amount highly_compensated_officer_5_name  \
# 0                                  NaN                               NaN
# 1                                  NaN                               NaN
# 2                             305000.0                   DEREK  PAQUETTE
# 3                                  NaN                               NaN
# 4                                  NaN                               NaN
#
#    highly_compensated_officer_5_amount  \
# 0                                  NaN
# 1                                  NaN
# 2                             300020.0
# 3                                  NaN
# 4                                  NaN
#
#                                usaspending_permalink   last_modified_date
# 0  https://www.usaspending.gov/award/CONT_AWD_N00...  2021-12-22 11:14:33
# 1  https://www.usaspending.gov/award/CONT_AWD_W91...  2022-04-12 20:11:25
# 2  https://www.usaspending.gov/award/CONT_AWD_N00...  2022-06-21 11:59:49
# 3  https://www.usaspending.gov/award/CONT_AWD_FA5...  2022-03-16 05:00:30
# 4  https://www.usaspending.gov/award/CONT_AWD_W91...  2021-12-07 22:35:16

# %%
test22['current_total_value_of_award'].sum()
# Out:
# 869869774949.87

# %%
sub = pd.DataFrame({'count' : test22.groupby( ['awarding_sub_agency_name'] ).size()}).reset_index()
sub
# Out:
#                              awarding_sub_agency_name  count
# 0   DEFENSE ADVANCED RESEARCH PROJECTS AGENCY  (DA...     65
# 1                   DEFENSE COMMISSARY AGENCY  (DECA)    827
# 2           DEFENSE CONTRACT MANAGEMENT AGENCY (DCMA)   2719
# 3     DEFENSE COUNTERINTELLIGENCE AND SECURITY AGENCY    182
# 4       DEFENSE FINANCE AND ACCOUNTING SERVICE (DFAS)    211
# 5                         DEFENSE HEALTH AGENCY (DHA)   2251
# 6                    DEFENSE HUMAN RESOURCES ACTIVITY    206
# 7           DEFENSE INFORMATION SYSTEMS AGENCY (DISA)  25287
# 8                            DEFENSE LOGISTICS AGENCY  11563
# 9                        DEFENSE MEDIA ACTIVITY (DMA)    110
# 10           DEFENSE MICROELECTRONICS ACTIVITY (DMEA)     92
# 11             DEFENSE THREAT REDUCTION AGENCY (DTRA)    280
# 12         DEPT OF DEFENSE EDUCATION ACTIVITY (DODEA)    729
# 13                              DEPT OF THE AIR FORCE  31091
# 14                                   DEPT OF THE ARMY  57632
# 15                                   DEPT OF THE NAVY  52717
# 16                       INSPECTOR GENERAL, OFFICE OF      1
# 17                       MISSILE DEFENSE AGENCY (MDA)    192
# 18                           SPACE DEVELOPMENT AGENCY     11
# 19                                 U.S. CYBER COMMAND     27
# 20          U.S. SPECIAL OPERATIONS COMMAND (USSOCOM)   2075
# 21  UNIFORMED SERVICES UNIVERSITY OF THE HEALTH SC...    151
# 22                                         USTRANSCOM   3539
# 23             WASHINGTON HEADQUARTERS SERVICES (WHS)   1739

# %%
sub.dtypes
# Out:
# dtype('int64')
